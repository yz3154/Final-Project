# %%
import pandas as pd
path='C:\\Users\\yz315\\Desktop\\listings.csv'
df=pd.read_csv(path)
df
# Out:
#             id                                               name    host_id  \
# 0     14485372  Family Friendly 2 Bedrooms 1 Bath w. washer/dryer   89361094
# 1     14446960        Cozy 3 Bedroom, 20 Minutes to Times Square!   88960729
# 2     14486192  Studio with perfect location 1/2 block from Su...   10099617
# 3     14486539            Welcome to your private room in my home   26267606
# 4     14448231  Cozy Sun Filled Fresh Guest Room in Artsy Bush...   22246463
# 5     14486682                 Chic 1 br with huge private garden    1206310
# 6     14449733        Furnished Lovely Room in 3 Bedroom Apt | EV   26592858
# 7     14450268                          Bedroom#3 and Event Space   65109990
# 8     14487072                         Private room with own T.V.   52577963
# 9     14450837    Yoga Apartment next to La Guardia and Manhattan   89000911
# 10    14488817                  Two bedrooms accommodate 4 guests    2766755
# ...

# %%
df.shape
# Out:
# (8928, 16)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8928, step=1)

# %%
df.columns=[var.upper() for var in df.columns]
df
# Out:
#             ID                                               NAME    HOST_ID  \
# 0     14485372  Family Friendly 2 Bedrooms 1 Bath w. washer/dryer   89361094
# 1     14446960        Cozy 3 Bedroom, 20 Minutes to Times Square!   88960729
# 2     14486192  Studio with perfect location 1/2 block from Su...   10099617
# 3     14486539            Welcome to your private room in my home   26267606
# 4     14448231  Cozy Sun Filled Fresh Guest Room in Artsy Bush...   22246463
# 5     14486682                 Chic 1 br with huge private garden    1206310
# 6     14449733        Furnished Lovely Room in 3 Bedroom Apt | EV   26592858
# 7     14450268                          Bedroom#3 and Event Space   65109990
# 8     14487072                         Private room with own T.V.   52577963
# 9     14450837    Yoga Apartment next to La Guardia and Manhattan   89000911
# 10    14488817                  Two bedrooms accommodate 4 guests    2766755
# ...

# %%
namelist=['NEIGHBOURHOOD','ROOM_TYPE','PRICE','MINIMUM_NIGHTS','NUMBER_OF_REVIEWS','LAST_REVIEW','REVIEWS_PER_MONTH',
          'CALCULATED_HOST_LISTINGS_COUNT','AVAILABILITY_365']
df_1=df[namelist]
df_1
# Out:
#                   NEIGHBOURHOOD        ROOM_TYPE  PRICE  MINIMUM_NIGHTS  \
# 0                   East Harlem  Entire home/apt    289               2
# 1                      Woodside  Entire home/apt    199               3
# 2               Upper East Side  Entire home/apt    101               5
# 3              Prospect Heights     Private room    100               3
# 4                      Bushwick     Private room     99               2
# 5                      Bushwick  Entire home/apt    120              10
# 6                  East Village     Private room     71              30
# 7                  Clinton Hill     Private room    105               1
# 8                     Woodhaven     Private room     45               5
# 9               Jackson Heights     Private room     40               1
# 10                       Harlem     Private room    399               3
# 11                   Greenpoint  Entire home/apt    150               4
# ...

# %%
df_1.mean()
# Out:
# PRICE                             142.057908
# MINIMUM_NIGHTS                      6.524194
# NUMBER_OF_REVIEWS                  23.452061
# REVIEWS_PER_MONTH                   1.420378
# CALCULATED_HOST_LISTINGS_COUNT      4.186380
# AVAILABILITY_365                  113.621304
# dtype: float64

# %%
df_1.describe()
# Out:
#              PRICE  MINIMUM_NIGHTS  NUMBER_OF_REVIEWS  REVIEWS_PER_MONTH  \
# count  8928.000000     8928.000000        8928.000000        7600.000000
# mean    142.057908        6.524194          23.452061           1.420378
# std     180.800669       15.056954          33.216514           1.650077
# min       0.000000        1.000000           0.000000           0.040000
# 25%      65.000000        2.000000           2.000000           0.230000
# 50%     100.000000        3.000000           8.000000           0.710000
# 75%     170.000000        5.000000          34.000000           2.220000
# max    5700.000000      365.000000         377.000000          17.170000
#
#        CALCULATED_HOST_LISTINGS_COUNT  AVAILABILITY_365
# count                     8928.000000       8928.000000
# mean                         4.186380        113.621304
# std                         13.460412        132.792809
# min                          1.000000          0.000000
# ...

# %%
print(df_1['PRICE'].plot(kind='barh',figsize=(10,20)))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df_1.describe().boxplot(figsize=(20,10))

# %%
df_2=df_1['PRICE']
df_2
# Out:
# 0       289
# 1       199
# 2       101
# 3       100
# 4        99
# 5       120
# 6        71
# 7       105
# 8        45
# 9        40
# 10      399
# 11      150
# 12       60
# 13       99
# 14      199
# 15      100
# 16       69
# 17      170
# 18      217
# 19      150
# 20      200
# 21      144
# 22       30
# 23      149
# 24      100
# 25       50
# 26      330
# 27       50
# 28      310
# 29      110
#        ...
# 8898     99
# 8899     35
# 8900    150
# 8901     87
# 8902     50
# 8903     80
# 8904     80
# 8905    190
# 8906     50
# 8907    151
# 8908    199
# 8909     52
# 8910     44
# 8911     78
# 8912     38
# 8913     73
# 8914    300
# 8915    300
# 8916    250
# 8917    215
# 8918    220
# 8919    139
# 8920     75
# 8921    175
# 8922    250
# 8923    110
# 8924    225
# 8925    168
# 8926    250
# 8927    105
# Name: PRICE, Length: 8928, dtype: int64

# %%
print(df_2.plot(kind='barh'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
df_3=df_1[['NEIGHBOURHOOD','PRICE']]
df_3
# Out:
#                   NEIGHBOURHOOD  PRICE
# 0                   East Harlem    289
# 1                      Woodside    199
# 2               Upper East Side    101
# 3              Prospect Heights    100
# 4                      Bushwick     99
# 5                      Bushwick    120
# 6                  East Village     71
# 7                  Clinton Hill    105
# 8                     Woodhaven     45
# 9               Jackson Heights     40
# 10                       Harlem    399
# 11                   Greenpoint    150
# 12                      Jamaica     60
# 13                       Harlem     99
# 14                 West Village    199
# 15               Sheepshead Bay    100
# 16                       Harlem     69
# 17                    Chinatown    170
# 18                   Greenpoint    217
# 19                 Williamsburg    150
# 20                  Fort Greene    200
# 21              Lower East Side    144
# 22           Bedford-Stuyvesant     30
# ...

# %%
df_4=df_3.groupby('NEIGHBOURHOOD')['PRICE'].count()
df_4
# Out:
# NEIGHBOURHOOD
# Allerton                        3
# Arrochar                        6
# Arverne                        22
# Astoria                       172
# Bath Beach                      4
# Battery Park City               6
# Bay Ridge                      28
# Bay Terrace, Staten Island      1
# Baychester                      3
# Bayside                        10
# Bedford-Stuyvesant            662
# Bellerose                       1
# Belmont                         2
# Bensonhurst                    16
# Bergen Beach                    2
# Boerum Hill                    32
# Borough Park                   14
# Briarwood                      11
# Brighton Beach                  9
# Bronxdale                       9
# Brooklyn Heights               31
# Brownsville                    14
# Bushwick                      464
# Cambria Heights                 4
# Canarsie                       25
# Carroll Gardens                42
# Castle Hill                     1
# ...

# %% [markdown]
# # Picking Top 10 neighbourhoods

# %%
df_4.sort_values()
# Out:
# NEIGHBOURHOOD
# Jamaica Estates                 1
# Mariners Harbor                 1
# Holliswood                      1
# Howland Hook                    1
# Huguenot                        1
# Little Neck                     1
# Castle Hill                     1
# Castleton Corners               1
# Dyker Heights                   1
# Neponsit                        1
# New Springville                 1
# Fort Wadsworth                  1
# Grant City                      1
# Unionport                       1
# Laurelton                       1
# Dongan Hills                    1
# Eltingville                     1
# Bay Terrace, Staten Island      1
# Soundview                       1
# Shore Acres                     1
# Westchester Square              1
# Bellerose                       1
# Prince's Bay                    1
# Port Morris                     1
# Eastchester                     1
# Olinville                       1
# Oakwood                         1
# ...

# %%
df_4.tail(10).plot(kind='barh')

# %%
import pandas as pd
df_5=pd.DataFrame({"NEIGHBOURHOOD":["Williamsburg","Bedford-Stuyvesant","Harlem", "Bushwick","Upper East Side",
                                    "Hell's Kitchen","Crown Heights","Upper West Side","East Village","Midtown"],
                   "PRICE":[138,150,135,149,141,172,152,136,128,130]})
df_5
# Out:
#         NEIGHBOURHOOD  PRICE
# 0        Williamsburg    138
# 1  Bedford-Stuyvesant    150
# 2              Harlem    135
# 3            Bushwick    149
# 4     Upper East Side    141
# 5      Hell's Kitchen    172
# 6       Crown Heights    152
# 7     Upper West Side    136
# 8        East Village    128
# 9             Midtown    130

# %%
df_6=df_5.set_index(['NEIGHBOURHOOD'])
df_6
# Out:
#                     PRICE
# NEIGHBOURHOOD
# Williamsburg          138
# Bedford-Stuyvesant    150
# Harlem                135
# Bushwick              149
# Upper East Side       141
# Hell's Kitchen        172
# Crown Heights         152
# Upper West Side       136
# East Village          128
# Midtown               130

# %%
df_6.plot(kind='barh')
